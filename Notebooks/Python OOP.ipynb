# %% [markdown]
# # Introduction to OOP in Python

# %% [markdown]
# ## A simple class

# %%
class Dog:
  
  # Initializer
  def __init__(self, name, age):
    self.name = name
    self.age = age

# %%
Dog("Maya", 5)

# %%
a = Dog("Philo", 6)
b = Dog("Mikey", 5)
a == b
# Out:
# False

# %%
print(a.name, "is", a.age)
print(b.name, "is", b.age)
# Out:
# Philo is 6
# Mikey is 5

# %% [markdown]
# ### Call by object reference

# %%
c = a
c.age = 10

print(a.name, "is", a.age)
print(c.name, "is", c.age)
# Out:
# Philo is 10
# Philo is 10

# %% [markdown]
# ## A class with instance methods and a class attribute

# %%
class Dog:
  
  # Class attribute
  species = "Mammal"
  
  # Initializer
  def __init__(self, name, age):
    self.name = name
    self.age = age
    
  # Instance method
  def description(self):
    return "{} is {} years old".format(self.name, self.age)
  
  # Instance methods
  def speak(self, sound):
    return "{} says {}!".format(self.name, sound)

# %%
mikey = Dog("Mikey", 11)

# %%
print(mikey.description())
print(mikey.speak("Hi"))
# Out:
# Mikey is 11 years old
# Mikey says Hi!

# %%
print(mikey.species)
# Out:
# Mammal

# %% [markdown]
# ## Inheritance

# %%
# Parent Class
class Dog:
  
  # Class attribute
  species = "Mammal"
  height_ave = 30
  
  # Initializer
  def __init__(self, name, age):
    self.name = name
    self.age = age
    
  # Instance method
  def description(self):
    return "{} is {} years old".format(self.name, self.age)
  
  # Instance methods
  def speak(self, sound):
    return "{} says {}!".format(self.name, sound)
  
  
# Child Class
class RussellTerrier(Dog):
  
  height_ave = 40
  
  def run(self, speed):
      return "{} runs {}".format(self.name, speed)

# Child Class
class Bulldog(Dog):
  
  height_ave = 20
  
  def run(self, speed):
      return "{} runs {}".format(self.name, speed)

# %%
# Child classes inherit attributes from the parent class
jim = Bulldog("Jim", 12)
print(isinstance(jim, Dog))
# Out:
# True

# %%
print(jim.description())
print(jim.height_ave)
print(jim.run("slowly"))
# Out:
# Jim is 12 years old
# 20
# Jim runs slowly
